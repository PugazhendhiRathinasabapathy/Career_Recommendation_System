# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt

# %%
df_occ = pd.read_excel("./data/Occupation Data.xlsx")
df_jz = pd.read_excel("./data/Job Zones.xlsx")
df_jzf = pd.read_excel("./data/Job Zone Reference.xlsx")
df_int = pd.read_excel("./data/Interests.xlsx")
df_know = pd.read_excel("./data/Knowledge.xlsx")
df_skill = pd.read_excel("./data/Skills.xlsx")
df_tools = pd.read_excel("./data/Tools Used.xlsx")
df_tech = pd.read_excel("./data/Technology Skills.xlsx")
df_scale = pd.read_excel("./data/Scales Reference.xlsx")
df_cont = pd.read_excel("./data/Content Model Reference.xlsx")
df_edu = pd.read_excel("./data/Education, Training, and Experience Categories.xlsx")

# %%
df_merged = pd.read_excel("./data/Final_Occupation_Data_Cleaned.xlsx")

# %%
df_merged.head(100)
# Out:
#    O*NET-SOC Code                                         Title  \
# 0      11-1011.00                              Chief Executives
# 1      11-1011.03                 Chief Sustainability Officers
# 2      11-1021.00               General and Operations Managers
# 3      11-2011.00           Advertising and Promotions Managers
# 4      11-2021.00                            Marketing Managers
# ..            ...                                           ...
# 95     15-1211.01                Health Informatics Specialists
# 96     15-1212.00                 Information Security Analysts
# 97     15-1221.00  Computer and Information Research Scientists
# 98     15-1231.00          Computer Network Support Specialists
# 99     15-1232.00             Computer User Support Specialists
#
#                                           Description  \
# 0   Determine and formulate policies and provide o...
# 1   Communicate and coordinate with management, sh...
# ...
